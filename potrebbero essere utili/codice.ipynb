# %%
import pandas as pd
import numpy as np

# %%
# path_acled  = "C:/Users/Lorenzo/Desktop/uni/ACCADEMICO/DV/DV_Datasets/DV_Datasets/ironneverden3/data/final/ACLED_grouped_events_gid.csv"

proper_path = "C:/Users/Lorenzo/Desktop/GithHub/DataVizualization/"
path_acled = proper_path + "ironneverden/data/final/ACLED_grouped_events_gid.csv"

# %%
data_acled = pd.read_csv(path_acled)

# %%
data_acled.columns
# Out:
# Index(['WEEK', 'REGION', 'COUNTRY', 'ADMIN1', 'EVENT_TYPE', 'SUB_EVENT_TYPE',
#        'EVENTS', 'FATALITIES', 'POPULATION_EXPOSURE', 'DISORDER_TYPE',
#        'CENTROID_LATITUDE', 'CENTROID_LONGITUDE', 'YEAR', 'ISO', 'GID_1'],
#       dtype='object')

# %%
df_country_summary = data_acled.groupby(['ISO', 'COUNTRY', 'YEAR', 'EVENT_TYPE', 'SUB_EVENT_TYPE'])['EVENTS'].sum().reset_index()
df_country_summary
# Out:
#       ISO  COUNTRY  YEAR                  EVENT_TYPE  \
# 0     ALB  Albania  2018                     Battles
# 1     ALB  Albania  2018  Explosions/Remote violence
# 2     ALB  Albania  2018                    Protests
# 3     ALB  Albania  2018                       Riots
# 4     ALB  Albania  2018                       Riots
# ...   ...      ...   ...                         ...
# 1922  XKO   Kosovo  2025  Explosions/Remote violence
# 1923  XKO   Kosovo  2025                    Protests
# 1924  XKO   Kosovo  2025                    Protests
# 1925  XKO   Kosovo  2025                       Riots
# 1926  XKO   Kosovo  2025  Violence against civilians
#
#                      SUB_EVENT_TYPE  EVENTS
# 0                       Armed clash       1
# 1     Remote explosive/landmine/IED       3
# 2                  Peaceful protest     211
# 3                      Mob violence       1
# 4             Violent demonstration      25
# ...                             ...     ...
# 1922                        Grenade       1
# 1923               Peaceful protest      59
# 1924      Protest with intervention       3
# 1925                   Mob violence       2
# 1926                         Attack       6
#
# [1927 rows x 6 columns]

# %%
df_admin_summary = data_acled.groupby(['ISO', 'COUNTRY', 'YEAR', 'GID_1','EVENT_TYPE','SUB_EVENT_TYPE'])['EVENTS'].sum().reset_index()
df_admin_summary
# Out:
#        ISO  COUNTRY  YEAR     GID_1                  EVENT_TYPE  \
# 0      ALB  Albania  2018  ALB.10_1                    Protests
# 1      ALB  Albania  2018  ALB.10_1                       Riots
# 2      ALB  Albania  2018  ALB.11_1  Explosions/Remote violence
# 3      ALB  Albania  2018  ALB.11_1                    Protests
# 4      ALB  Albania  2018  ALB.11_1                       Riots
# ...    ...      ...   ...       ...                         ...
# 11240  XKO   Kosovo  2025   XKO.5_1                    Protests
# 11241  XKO   Kosovo  2025   XKO.5_1                    Protests
# 11242  XKO   Kosovo  2025   XKO.5_1  Violence against civilians
# 11243  XKO   Kosovo  2025   XKO.6_1  Violence against civilians
# 11244  XKO   Kosovo  2025   XKO.7_1                    Protests
#
#                       SUB_EVENT_TYPE  EVENTS
# 0                   Peaceful protest       7
# 1              Violent demonstration       2
# 2      Remote explosive/landmine/IED       3
# 3                   Peaceful protest     115
# 4              Violent demonstration      17
# ...                              ...     ...
# 11240               Peaceful protest      36
# 11241      Protest with intervention       1
# 11242                         Attack       1
# 11243                         Attack       1
# 11244               Peaceful protest       4
#
# [11245 rows x 7 columns]
